# %% [markdown]
# # Task 1: Data Exploration and Preprocessing

# %% [markdown]
# 1.1 Define the dataset as individual documents

# %%
# Defining the dataset as individual documents
doc_1 = "Enhancing Few-Shot Learning for Medical Imaging with Transformer-Based Models.Few-shot learning in medical imaging presents unique challenges due to data scarcity and high variability. This paper explores transformer-based architectures to enhance few-shot learning performance in radiology. Using cross-attention mechanisms, our model achieves a 12% accuracy boost compared to CNNs on the NIH Chest X-Ray dataset"

doc_2 = "Towards Real-Time Cyber Threat Detection in IoT Networks using Graph Neural Networks.The rise of IoT devices has increased cyber threats. This paper introduces a graph neural network (GNN) model to detect threats in IoT networks. Representing device interactions as a graph and applying GNN, we achieved a 15% improvement in detection rate over rule-based systems."

doc_3 = "Privacy-Preserving Federated Learning with Differential Privacy for Health Data.Federated learning is ideal for decentralized health data, but privacy remains a concern. We integrate differential privacy into federated frameworks to protect patient data while maintaining model accuracy, achieving an AUC of 0.85 on real-world health records."

doc_4 = "Deep Learning Models for RNA-Seq Data Analysis in Cancer Genomics.RNA-Seq data analysis is crucial for cancer genomics. This study applies deep learning models to classify cancer types based on gene expression profiles. Our models achieve a 92% classification accuracy on TCGA datasets, significantly outperforming traditional machine learning methods."

doc_5 = "Quantum Computing Algorithms for Optimization Problems: A Survey.This survey reviews quantum computing algorithms for solving NP-hard optimization problems. We focus on the Quantum Approximate Optimization Algorithm (QAOA) and Grover's algorithm, discussing their limitations and potential applications in finance, logistics, and AI."

doc_6 = "Multi-Agent Reinforcement Learning for Cooperative Robotic Systems.With autonomous robotic systems on the rise, coordinating multiple agents is crucial. This paper presents a multi-agent reinforcement learning (MARL) framework for collaborative tasks, yielding a 20% efficiency improvement in simulations over single-agent learning."

doc_7 = "Cloud Resource Optimization for HPC Workloads using Deep Reinforcement Learning.Optimizing cloud resources for HPC workloads is vital for efficiency. Our deep reinforcement learning-based model adapts to workload demands, reducing latency and cost by 25% compared to static allocation methods, making it ideal for cloud-based HPC."

doc_8 = "Emotion-Aware NLP for Sentiment Analysis in Social Media.Social media is a rich source of sentiment data. This paper introduces an emotion-aware NLP model for social media text, achieving 87% accuracy on Twitter data. The model captures nuanced emotions, outperforming standard sentiment classification models."

doc_9 = "Efficient DNA Sequence Alignment using Attention-Based Deep Learning Models.DNA sequence alignment is computationally intensive. We propose an attention-based deep learning model to accelerate alignment, achieving a 10x speed improvement over standard algorithms while maintaining accuracy, especially on large genomic datasets."

doc_10 = "Automated Protein Structure Prediction with Graph Neural Networks.Protein structure prediction is critical in bioinformatics. Our study uses graph neural networks to model protein structures, achieving a mean RMSD improvement of 20% over traditional methods. This approach can facilitate drug discovery and precision medicine."

doc_11 = "Predicting Protein-Protein Interactions with Machine Learning.Protein-protein interactions (PPIs) play a key role in cellular processes. This paper introduces a machine learning model that predicts PPIs based on sequence and structural features, achieving 85% accuracy, which can aid drug target identification."

doc_12 = "Secure Federated Learning in Healthcare Applications: A Blockchain Approach.Federated learning in healthcare is limited by privacy concerns. We propose a blockchain-based framework to enhance security in federated learning, allowing decentralized data sharing while ensuring privacy and traceability in healthcare applications."

doc_13 = "Image Super-Resolution in Medical Imaging using GANs.Medical image quality is crucial for accurate diagnosis. This study uses generative adversarial networks (GANs) to improve image resolution, achieving superior performance in generating high-resolution images from low-resolution counterparts in CT and MRI scans."

doc_14 = "Bioinformatics Pipelines for Integrative Multi-Omics Analysis.Integrative multi-omics is increasingly used to understand complex diseases. This paper introduces a bioinformatics pipeline that combines genomics, transcriptomics, and metabolomics data, providing a comprehensive view of disease mechanisms in Alzheimer’s."

doc_15 = "Adversarial Training for Robust Machine Learning Models in Cybersecurity.Machine learning in cybersecurity is vulnerable to adversarial attacks. This paper proposes a robust training method using adversarial samples, improving model resilience by 18% in intrusion detection on real-world datasets."

doc_16 = "Predicting Adverse Drug Reactions using Knowledge Graphs and Machine Learning.Adverse drug reactions (ADRs) are a significant health risk. We use knowledge graphs combined with machine learning to predict ADRs based on drug and patient data, achieving an AUC of 0.87 on FDA ADR databases, which can inform safer drug prescriptions."

doc_17 = "Real-Time Autonomous Drone Navigation using Reinforcement Learning.Autonomous drones require real-time decision-making for navigation. This study implements a reinforcement learning model that enables drones to navigate complex environments with minimal human intervention, achieving a 90% success rate in obstacle-rich settings."

doc_18 = "Natural Language Generation in Conversational Agents for Customer Support.Conversational agents are increasingly used in customer support. This paper presents a natural language generation model fine-tuned for customer service contexts, achieving a 15% reduction in response time and improved user satisfaction."

doc_19 = "Explainable AI for Genomic Data Interpretation in Cancer Research.Interpretability in AI models is essential for genomic research. We introduce an explainable AI framework to analyze genomic data for cancer, providing insight into critical biomarkers. Our approach improves clinician trust in AI-generated insights by offering interpretable predictions."

doc_20 = "Deep Learning for Predicting Protein Secondary Structure from Amino Acid Sequences.Predicting protein secondary structure is fundamental to understanding protein function. We propose a deep learning model that predicts secondary structures with an accuracy of 83%, which could enhance protein engineering and drug discovery efforts."
# Create corpus
corpus = [doc_1, doc_2, doc_3, doc_4, doc_5,doc_6,doc_7,doc_8,doc_9,doc_10,doc_11,doc_12,doc_13,doc_14,doc_15,doc_16,doc_17,doc_18,doc_19,doc_20]

# %%
# Inspect dataset
for i, doc in enumerate(corpus[:3]):  # Display the first 3 abstracts
    print(f"Doc {i + 1}:\n{doc}\n{'-' * 50}")
# Out:
# Doc 1:
# Enhancing Few-Shot Learning for Medical Imaging with Transformer-Based Models.Few-shot learning in medical imaging presents unique challenges due to data scarcity and high variability. This paper explores transformer-based architectures to enhance few-shot learning performance in radiology. Using cross-attention mechanisms, our model achieves a 12% accuracy boost compared to CNNs on the NIH Chest X-Ray dataset
# --------------------------------------------------
# Doc 2:
# Towards Real-Time Cyber Threat Detection in IoT Networks using Graph Neural Networks.The rise of IoT devices has increased cyber threats. This paper introduces a graph neural network (GNN) model to detect threats in IoT networks. Representing device interactions as a graph and applying GNN, we achieved a 15% improvement in detection rate over rule-based systems.
# --------------------------------------------------
# Doc 3:
# ...

# %%
# Import necessary libraries for text preprocessing
import string
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/user1-system11/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/user1-system11/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/user1-system11/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# remove stopwords, punctuation, and normalize the corpus
stop = set(stopwords.words('english')) | {"paper", "study", "data"}
exclude = set(string.punctuation)
lemma = WordNetLemmatizer()

# %% [markdown]
# 1.2 Preprocessing

# %%
import nltk
nltk.download('punkt_tab')

# Preprocess the text data:
def preprocess_text(doc):
    # Tokenization and lowercase
    tokens = nltk.word_tokenize(doc.lower())  # Robust tokenization with nltk

    # Remove stop words
    stop_free = [token for token in tokens if token not in stop]

    # Remove punctuation
    punc_free = [token for token in stop_free if token not in exclude]

    # Lemmatization
    normalized = [lemma.lemmatize(token) for token in punc_free]

    return normalized

# Preprocess the corpus
clean_corpus = [preprocess_text(doc) for doc in corpus]
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/user1-system11/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
clean_corpus
# Out:
# [['enhancing',
#   'few-shot',
#   'learning',
#   'medical',
#   'imaging',
#   'transformer-based',
#   'models.few-shot',
#   'learning',
#   'medical',
#   'imaging',
#   'present',
#   'unique',
#   'challenge',
#   'due',
#   'scarcity',
#   'high',
#   'variability',
#   'explores',
#   'transformer-based',
#   'architecture',
#   'enhance',
#   'few-shot',
#   'learning',
#   'performance',
#   'radiology',
#   'using',
#   'cross-attention',
#   'mechanism',
#   'model',
#   'achieves',
#   '12',
#   'accuracy',
#   'boost',
#   'compared',
#   'cnns',
#   'nih',
#   'chest',
#   'x-ray',
#   'dataset'],
#  ['towards',
#   'real-time',
#   'cyber',
#   'threat',
#   'detection',
#   'iot',
#   'network',
#   'using',
#   'graph',
#   'neural',
#   'networks.the',
#   'rise',
#   'iot',
#   'device',
#   'increased',
#   'cyber',
#   'threat',
#   'introduces',
#   'graph',
#   'neural',
#   'network',
#   'gnn',
#   'model',
#   'detect',
#   'threat',
#   'iot',
# ...

# %%
## Create a dictionary and corpus for Gensim

from gensim.corpora.dictionary import Dictionary

gensim_dict = Dictionary(clean_corpus)
gensim_corpus = [gensim_dict.doc2bow(text) for text in clean_corpus]

# %% [markdown]
# # Task 2: Building a Topic Model

# %% [markdown]
# 2.1 Define a function to train an LDA model

# %%
from sklearn.decomposition import LatentDirichletAllocation
import numpy as np
from gensim.models import CoherenceModel
from gensim.corpora.dictionary import Dictionary

def train_lda_model(tfidf_matrix, num_topics, random_state=42):
    lda_model = LatentDirichletAllocation(n_components=num_topics, random_state=random_state)
    lda_model.fit(tfidf_matrix)
    return lda_model

# %%
#extract topics
def extract_topics(lda_model, vectorizer, num_words=10):
    terms = vectorizer.get_feature_names_out()
    topics = [
        [terms[i] for i in topic.argsort()[-num_words:][::-1]]
        for topic in lda_model.components_
    ]
    return topics

# %% [markdown]
# 2.2 Hyperparameter tuning using coherence scores

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

coherence_scores = []
vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
tfidf_matrix = vectorizer.fit_transform([" ".join(doc) for doc in clean_corpus])

# %%
#Tested for 1-20 topics and saw improvement for 5–9 Topics and sharp increase beyond 10 topics. So, I choosed 5 to 20 topics at first and then moved to 8–12 and 12-15 for more granularity

# %%
#Choose an appropriate number of topics by testing various values using cohenrence scores
for num_topics in range(12,15): 
    lda_model = train_lda_model(tfidf_matrix, num_topics)
    topics = extract_topics(lda_model, vectorizer)
    coherence_model = CoherenceModel(
        topics=topics, texts=clean_corpus, dictionary=gensim_dict, coherence='c_v'
    )
    coherence = coherence_model.get_coherence()
    coherence_scores.append((num_topics, coherence))
    print(f"Num Topics: {num_topics}, Coherence: {coherence:.4f}")
# Out:
# Num Topics: 12, Coherence: 0.5375
# Num Topics: 13, Coherence: 0.4646
# Num Topics: 14, Coherence: 0.4515

# %%
# Select the best number of topics
best_num_topics = max(coherence_scores, key=lambda x: x[1])[0]
print(f"\nOptimal number of topics: {best_num_topics}")
# Out:
# Optimal number of topics: 12

# %% [markdown]
# 2.3 Model Fitting:

# %%
# Train final LDA model
final_lda_model = train_lda_model(tfidf_matrix, best_num_topics)
final_topics = extract_topics(final_lda_model, vectorizer)

# %%
# Display topics
print("\nTopics:")
for i, topic in enumerate(final_topics):
    print(f"Topic {i+1}: {', '.join(topic)}")
# Out:
# Topics:
# Topic 1: disease, omics, integrative, pipeline, bioinformatics, multi, view, alzheimer, transcriptomics, metabolomics
# Topic 2: ai, adversarial, genomic, training, cybersecurity, robust, explainable, research, insight, machine
# Topic 3: agent, image, resolution, robotic, multi, gans, reinforcement, medical, crucial, learning
# Topic 4: algorithm, privacy, alignment, quantum, health, federated, optimization, dna, differential, attention
# Topic 5: cancer, rna, seq, genomics, analysis, deep, learning, model, significantly, gene
# Topic 6: protein, drone, reinforcement, secondary, deep, hpc, workload, cloud, structure, learning
# Topic 7: achieving, model, accuracy, using, based, introduces, improvement, framework, method, drug
# Topic 8: structure, protein, prediction, neural, graph, medicine, mean, facilitate, precision, automated
# Topic 9: shot, drug, learning, adverse, adrs, knowledge, reaction, transformer, imaging, medical
# ...

# %% [markdown]
# #giving label to each topics:
# <!--
# Topic 1	Integrative Omics and Disease Mechanisms
# Topic 2	AI in Cybersecurity and Genomics
# Topic 3	Medical Imaging and Multi-Agent Systems
# Topic 4	Privacy-Preserving Algorithms in Quantum and Health
# Topic 5	Genomics and RNA-Seq in Cancer Research
# Topic 6	Protein Structure and HPC Workloads
# Topic 7	Model Accuracy and Drug Discovery Frameworks
# Topic 8	Graph Neural Networks for Protein Structure Prediction
# Topic 9	Adverse Drug Reactions and Medical Transformers
# Topic 10	Sentiment Analysis and Conversational AI
# Topic 11	Protein-Protein Interactions and Cellular Processes
# Topic 12	Federated Learning and Blockchain in Healthcare -->

# %% [markdown]
# # Task 3: Visualizing and Interpreting the results

# %% [markdown]
# 3.1 Visualization

# %%
#Using PyLDAvis 
import pyLDAvis

# Calculate the required parameters for PyLDAvis
topic_term_dists = final_lda_model.components_ / final_lda_model.components_.sum(axis=1)[:, np.newaxis]
doc_topic_dists = final_lda_model.transform(tfidf_matrix)
vocab = vectorizer.get_feature_names_out()
term_frequency = tfidf_matrix.sum(axis=0).A1
doc_lengths = [len(doc) for doc in clean_corpus]  # Number of tokens in each document

# Prepare the visualization
visualization = pyLDAvis.prepare(
    topic_term_dists=topic_term_dists,
    doc_topic_dists=doc_topic_dists,
    doc_lengths=doc_lengths,
    vocab=vocab,
    term_frequency=term_frequency
)

# Display visualization
pyLDAvis.display(visualization)
# Out:
# /home/user1-system11/miniconda3/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=3012232) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/user1-system11/miniconda3/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=3012232) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/user1-system11/miniconda3/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=3012232) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/user1-system11/miniconda3/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=3012232) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# ...

# %% [markdown]
# Interpretation: The PyLDAvis visualizations show well-separated clusters for some topics (e.g., Topic 1 and Topic 2), while others like Topics 11 and 12 are closely aligned, which reflects the shared thematic elements in those areas. Topics 6, 8, and 11 appear closely clustered indicating overlapping terms or themes, particularly in protein-related research. Topics like 3 and 10 are moderately isolated, representing unique research areas such as robotics and customer sentiment.

# %%
#Using WordCloud

from wordcloud import WordCloud
import matplotlib.pyplot as plt

for i, topic in enumerate(final_topics):
    plt.figure()
    wordcloud = WordCloud(width=800, height=400, background_color='white')
    wordcloud.generate_from_frequencies(dict(zip(topic, final_lda_model.components_[i])))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f"Topic {i+1}")
    plt.show()

# %%
#Topic Prevalence
import seaborn as sns

# heatmap of topic contributions per document
doc_topic_distribution = final_lda_model.transform(tfidf_matrix)
plt.figure(figsize=(12, 8))
sns.heatmap(doc_topic_distribution, cmap="YlGnBu", annot=False)
plt.title("Topic Contribution Per Document")
plt.xlabel("Topics")
plt.ylabel("Documents")
plt.show()

# %% [markdown]
# Interpretation: Most documents are strongly aligned with a single topic, suggesting the topics are distinct and meaningful. Topics that appear in fewer documents might represent niche themes or redundant content. Some topics (e.g., Topic 5 and Topic 8) appear less frequently across documents.

# %%
#Using bar chart
import matplotlib.pyplot as plt

topic_distribution = np.sum(final_lda_model.transform(tfidf_matrix), axis=0)  # Sum probabilities across all documents
plt.bar(range(1, best_num_topics + 1), topic_distribution)  # Use best_num_topics
plt.xlabel('Topic Number')
plt.ylabel('Document Share')
plt.title('Topic Prevalence')
plt.show()

# %% [markdown]
# Interpretation:
# Topic 6 has the highest prevalence, appearing in the largest number of documents. Topic 7 has the lowest prevalence, suggesting it is rarely the dominant topic in documents. The remaining topics (e.g., Topics 2, 3, 10) have similar prevalence, which reflects a balanced contribution of themes.

# %%
# Add a pairwise similarity plot between topics
topic_similarity = np.corrcoef(doc_topic_distribution.T)
plt.figure(figsize=(10, 8))
sns.heatmap(topic_similarity, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Topic Similarity Matrix")
plt.xlabel("Topics")
plt.ylabel("Topics")
plt.show()

# %% [markdown]
# Interpretation: Topics 6 and 8 show a significant negative correlation (-0.62), suggesting contrasting themes. This indicates that the topics are distinct and may represent opposing perspectives or contexts. Topics 10 and 11 have a moderate positive correlation (0.31), which might indicate some overlap or shared themes between these two topics. There are no strongly overlapping topics, meaning your model has done well in separating themes.

# %% [markdown]
# Topic Interpretation and reflection is in the final report doc file (attached separately).

# %%
""" Improvements made:
- Clearer segmentation of tasks for readability.
- Expanded visualizations including word clouds, topic prevalence charts, topic contribution heatmap, and topic similarity matrix.
- Updated Documentation with more detailed explanation
"""

# %%
# Topic Interpretation and reflection is in the final report doc file (attached separately).
